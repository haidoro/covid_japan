# %% [markdown]
# # 全国新型コロナウイルスデータ

# %% [markdown]
# ## jsonデータを読み込み

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker as ticker
mpl.rcParams['font.family'] = 'AppleGothic'

pcr = pd.read_csv('./PCR.csv')
data = pd.read_csv('./COVID-19.csv')
data_pcr = pd.merge(pcr, data, right_on='確定日',left_on='年月日')
data.head()
# Out:
#    通し 厚労省NO 無症状病原体保有者   国内 チャーター便   年代  性別        確定日        発症日 受診都道府県  \
# 0   1    1        NaN  A-1    NaN  30   男性  1/15/2020   1/3/2020   神奈川県
# 1   2    2        NaN  A-2    NaN  40   男性  1/24/2020  1/14/2020    東京都
# 2   3    3        NaN  A-3    NaN  30   女性  1/25/2020  1/21/2020    東京都
# 3   4    4        NaN  A-4    NaN  40   男性  1/26/2020  1/23/2020    愛知県
# 4   5    5        NaN  A-5    NaN  40   男性  1/28/2020  1/22/2020    愛知県
#
#     ...   居住都道府県コード            更新日時 Field2 Field4 Field5 Field6  Field7  \
# 0   ...        14.0  4/5/2020 21:45    NaN    NaN    NaN    NaN     NaN
# 1   ...         NaN             NaN    NaN    NaN    NaN    NaN     NaN
# 2   ...         NaN             NaN    NaN    NaN    NaN    NaN     NaN
# 3   ...         NaN             NaN    NaN    NaN    NaN    NaN     NaN
# 4   ...         NaN             NaN    NaN    NaN    NaN    NaN     NaN
#
#   Field8 Field9 Field10
# 0    NaN    NaN     NaN
# 1    NaN    NaN     NaN
# 2    NaN    NaN     NaN
# 3    NaN    NaN     NaN
# 4    NaN    NaN     NaN
#
# [5 rows x 51 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3805 entries, 0 to 3804
# Data columns (total 51 columns):
# 通し                  3805 non-null int64
# 厚労省NO               2693 non-null object
# 無症状病原体保有者           304 non-null object
# 国内                  302 non-null object
# チャーター便              11 non-null object
# 年代                  3805 non-null object
# 性別                  3804 non-null object
# 確定日                 3805 non-null object
# 発症日                 2241 non-null object
# 受診都道府県              3805 non-null object
# 居住都道府県              3805 non-null object
# 居住管内                100 non-null object
# 居住市区町村              2101 non-null object
# キー                  3805 non-null object
# 発表                  3805 non-null object
# 都道府県内症例番号           2961 non-null object
# 市町村内症例番号            737 non-null float64
# ステータス               114 non-null object
# 備考                  744 non-null object
# ソース                 2030 non-null object
# ソース2                2697 non-null object
# ソース3                787 non-null object
# 人数                  3805 non-null int64
# 累計                  73 non-null object
# 前日比                 73 non-null object
# 死者合計                65 non-null float64
# 退院数累計               55 non-null float64
# 退院数                 55 non-null float64
# 発症数                 72 non-null object
# PCR検査実施人数           33 non-null float64
# PCR検査前日比            33 non-null object
# 職業_正誤確認用            469 non-null object
# 勤務先_正誤確認用           36 non-null object
# Hospital Pref       3805 non-null object
# Residential Pref    3805 non-null object
# Release             3805 non-null object
# Gender              3805 non-null object
# X                   3805 non-null float64
# Y                   3805 non-null float64
# 確定日YYYYMMDD         3805 non-null object
# 受診都道府県コード           3721 non-null float64
# 居住都道府県コード           3681 non-null float64
# 更新日時                1 non-null object
# Field2              393 non-null object
# Field4              0 non-null float64
# Field5              0 non-null float64
# Field6              0 non-null float64
# Field7              0 non-null float64
# Field8              0 non-null float64
# Field9              0 non-null float64
# Field10             0 non-null float64
# dtypes: float64(16), int64(2), object(33)
# memory usage: 1.5+ MB

# %% [markdown]
# ## 症状別累計人数

# %%
total = int(data["累計"].iloc[-1])
d = int(data["死者合計"].dropna().iloc[-1])
di = int(data["退院数累計"].dropna().iloc[-1])
print(data["確定日"].iloc[-1],"現在データ")
print('全国の新型コロナウイルス感染者はトータル:',total,'死者合計:',d,'累計退院者数:',di)
print('死亡確率：{}%'.format((d/total)*100),'退院率：{}%'.format((di/total)*100))
# Out:
# 4/5/2020 現在データ
# 全国の新型コロナウイルス感染者はトータル: 3805 死者合計: 70 累計退院者数: 584
# 死亡確率：1.8396846254927726% 退院率：15.348226018396845%

# %% [markdown]
# ## 日別PCR検査数
# 厚生労働省の発表資料より
#
# PCR検査数は毎日更新ではありません。
#
# 厚生労働省が更新するたびに多少過去の数値が変更されたりしています。

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.plot(pcr['年月日'],pcr['数'])
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, fontsize=10);

# %% [markdown]
# ## 累計PCR検査数

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.plot(pcr['年月日'],pcr['PCR累計'])
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, fontsize=10);

# %%
data = data.convert_objects(convert_numeric=True)
data_day = data.dropna(subset=['累計'])
data_day.loc[:,['累計','確定日']]
# Out:
# /Users/tahara/.pyenv/versions/anaconda3-5.2.0/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
#           累計        確定日
# 0        1.0  1/15/2020
# 1        2.0  1/24/2020
# 2        3.0  1/25/2020
# 3        4.0  1/26/2020
# 6        7.0  1/28/2020
# 7        8.0  1/29/2020
# 13      14.0  1/30/2020
# 15      16.0  1/31/2020
# 18      19.0   2/1/2020
# 22      23.0   2/4/2020
# 24      25.0   2/5/2020
# 25      26.0   2/7/2020
# 27      28.0  2/10/2020
# 28      29.0  2/11/2020
# 32      33.0  2/13/2020
# 40      41.0  2/14/2020
# 52      53.0  2/15/2020
# 58      59.0  2/16/2020
# 65      66.0  2/17/2020
# 75      76.0  2/18/2020
# 84      85.0  2/19/2020
# 93      94.0  2/20/2020
# 110    111.0  2/21/2020
# 136    137.0  2/22/2020
# 146    147.0  2/23/2020
# 158    159.0  2/24/2020
# 173    174.0  2/25/2020
# 190    191.0  2/26/2020
# 215    216.0  2/27/2020
# 235    236.0  2/28/2020
# ...      ...        ...
# 650    651.0  3/11/2020
# 695    696.0  3/12/2020
# 736    737.0  3/13/2020
# 789    790.0  3/14/2020
# 820    821.0  3/15/2020
# 839    840.0  3/16/2020
# 885    886.0  3/17/2020
# 929    930.0  3/18/2020
# 971    972.0  3/19/2020
# 1020  1021.0  3/20/2020
# 1063  1064.0  3/21/2020
# 1105  1106.0  3/22/2020
# 1143  1144.0  3/23/2020
# 1222  1223.0  3/24/2020
# 1313  1314.0  3/25/2020
# 1323  1324.0  3/26/2020
# 1324  1325.0  3/25/2020
# 1416  1417.0  3/26/2020
# 1418  1419.0  3/27/2020
# 1421  1422.0  3/26/2020
# 1545  1546.0  3/27/2020
# 1751  1752.0  3/28/2020
# 1918  1919.0  3/29/2020
# 2060  2061.0  3/30/2020
# 2294  2295.0  3/31/2020
# 2573  2574.0   4/1/2020
# 2863  2864.0   4/2/2020
# 3194  3195.0   4/3/2020
# 3562  3563.0   4/4/2020
# 3804  3805.0   4/5/2020
#
# [71 rows x 2 columns]

# %% [markdown]
# ## 日別感染者累計

# %%
fig, ax = plt.subplots(figsize=(16,10))
ax.bar(data_day['確定日'],data_day['累計'])

labels = ax.get_xticklabels()
plt.setp(labels, rotation=90, fontsize=8);

# %% [markdown]
# ## 死亡者推移

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.bar(data['確定日'],data["死者合計"])
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, fontsize=8);

# %% [markdown]
# ## 年代別感染者数割合

# %%
x = data['年代'].value_counts(ascending=True)
label_index = data['年代'].value_counts(ascending=True).index
plt.figure(figsize=(10,10))
plt.pie(x, labels= label_index, startangle=90, labeldistance=1,rotatelabels=False,autopct='%.2f%%')
plt.legend()
plt.show()

# %% [markdown]
# ## 性別感染者数割合

# %%
x = data['性別'].value_counts(ascending=True)
label_index = data['性別'].value_counts(ascending=True).index
plt.figure(figsize=(10,10))
plt.pie(x, labels= label_index, startangle=90, labeldistance=1,rotatelabels=False,autopct='%.2f%%')
plt.legend()
plt.show()

# %% [markdown]
# ### 県別累計データ

# %%
grouped = data['人数'].groupby(data['居住都道府県'])
total_pref = grouped.sum()
total_pref = total_pref.sort_values(ascending=False) 
total_pref = pd.DataFrame(total_pref)
total_pref
# Out:
#             人数
# 居住都道府県
# 東京都       1035
# 大阪府        408
# 神奈川県       268
# 千葉県        244
# 愛知県        218
# 兵庫県        203
# 北海道        189
# 埼玉県        189
# 福岡県        146
# 京都府        123
# 不明          98
# 茨城県         54
# 福井県         53
# 岐阜県         53
# 新潟県         33
# 高知県         32
# 大分県         32
# 石川県         31
# 奈良県         26
# 群馬県         26
# 和歌山県        25
# 宮城県         22
# 滋賀県         21
# 愛媛県         21
# 熊本県         19
# 中華人民共和国     18
# 静岡県         17
# 沖縄県         16
# 福島県         15
# 栃木県         15
# 広島県         14
# 山梨県         14
# 三重県         12
# 岡山県         12
# 長崎県         11
# 長野県         11
# 秋田県         10
# 富山県         10
# 宮崎県          9
# 青森県          9
# 山形県          9
# 山口県          8
# 佐賀県          7
# 徳島県          3
# イギリス         3
# 鹿児島県         2
# アイルランド       2
# 南アフリカ共和国     1
# フランス         1
# フィリピン        1
# スペイン         1
# ジンバブエ共和国     1
# カナダ          1
# インドネシア       1
# 香川県          1
# アメリカ         1

# %%
location_data = pd.read_csv('./location.csv')
location_data.head()
# Out:
#   都道府県名        緯度         経度
# 0   北海道  43.06417  141.34694
# 1   青森県  40.82444  140.74000
# 2   岩手県  39.70361  141.15250
# 3   宮城県  38.26889  140.87194
# 4   秋田県  39.71861  140.10250

# %% [markdown]
# ### locationデータと感染者数をマージ

# %%
pref_data = pd.merge(total_pref, location_data, left_on='居住都道府県', right_on='都道府県名', how='outer')
pref_data['人数'] = pref_data['人数'].fillna(0)
pref_data = pref_data.dropna(subset=['都道府県名'])
pref_data
# Out:
#         人数 都道府県名        緯度         経度
# 0   1035.0   東京都  35.68944  139.69167
# 1    408.0   大阪府  34.68639  135.52000
# 2    268.0  神奈川県  35.44778  139.64250
# 3    244.0   千葉県  35.60472  140.12333
# 4    218.0   愛知県  35.18028  136.90667
# 5    203.0   兵庫県  34.69139  135.18306
# 6    189.0   北海道  43.06417  141.34694
# 7    189.0   埼玉県  35.85694  139.64889
# 8    146.0   福岡県  33.60639  130.41806
# 9    123.0   京都府  35.02139  135.75556
# 11    54.0   茨城県  36.34139  140.44667
# 12    53.0   福井県  36.06528  136.22194
# 13    53.0   岐阜県  35.39111  136.72222
# 14    33.0   新潟県  37.90222  139.02361
# 15    32.0   高知県  33.55972  133.53111
# 16    32.0   大分県  33.23806  131.61250
# 17    31.0   石川県  36.59444  136.62556
# 18    26.0   奈良県  34.68528  135.83278
# 19    26.0   群馬県  36.39111  139.06083
# 20    25.0  和歌山県  34.22611  135.16750
# 21    22.0   宮城県  38.26889  140.87194
# 22    21.0   滋賀県  35.00444  135.86833
# 23    21.0   愛媛県  33.84167  132.76611
# 24    19.0   熊本県  32.78972  130.74167
# 26    17.0   静岡県  34.97694  138.38306
# 27    16.0   沖縄県  26.21250  127.68111
# 28    15.0   福島県  37.75000  140.46778
# 29    15.0   栃木県  36.56583  139.88361
# 30    14.0   広島県  34.39639  132.45944
# 31    14.0   山梨県  35.66389  138.56833
# 32    12.0   三重県  34.73028  136.50861
# 33    12.0   岡山県  34.66167  133.93500
# 34    11.0   長崎県  32.74472  129.87361
# 35    11.0   長野県  36.65139  138.18111
# 36    10.0   秋田県  39.71861  140.10250
# 37    10.0   富山県  36.69528  137.21139
# 38     9.0   宮崎県  31.91111  131.42389
# 39     9.0   青森県  40.82444  140.74000
# 40     9.0   山形県  38.24056  140.36333
# 41     8.0   山口県  34.18583  131.47139
# 42     7.0   佐賀県  33.24944  130.29889
# 43     3.0   徳島県  34.06583  134.55944
# 45     2.0  鹿児島県  31.56028  130.55806
# 54     1.0   香川県  34.34028  134.04333
# 56     0.0   岩手県  39.70361  141.15250
# 57     0.0   鳥取県  35.50361  134.23833
# 58     0.0   島根県  35.47222  133.05056

# %%
pref_data_dic = pref_data.to_dict(orient='index')
states = tuple(pref_data_dic.values())

# %% [markdown]
# ## 県別感染者数Map表示
# Map表示はGitHubではできませんので、次のリンクから確認ください。
#
# [県別感染者数Map](https://haidoro.github.io/covid_japan/)

# %%
import folium
from folium.plugins import HeatMap

map_ = folium.Map(location=[35.684479, 139.747977], zoom_start=5)


# 円の大きさをわかりやすくするための重み
WEIGHT = 0.01


for state in states:
    folium.CircleMarker(
            [state['緯度'], state['経度']],
            radius=(state['人数'] + WEIGHT)*0.1,
            popup=state['都道府県名'],
            color='#3186cc',
            fill_color='#3186cc',
    ).add_to(map_)


map_.save('index.html')
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
