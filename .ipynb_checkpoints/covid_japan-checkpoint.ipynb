# %% [markdown]
# # 全国新型コロナウイルスデータ

# %% [markdown]
# ## jsonデータを読み込み

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['font.family'] = 'AppleGothic'


data = pd.read_csv('./COVID-19.csv')
data.head()
# Out:
#    通し 厚労省NO 無症状病原体保有者   国内 チャーター便   年代  性別        確定日        発症日 受診都道府県  \
# 0   1    1        NaN  A-1    NaN  30   男性  1/15/2020   1/3/2020   神奈川県
# 1   2    2        NaN  A-2    NaN  40   男性  1/24/2020  1/14/2020    東京都
# 2   3    3        NaN  A-3    NaN  30   女性  1/25/2020  1/21/2020    東京都
# 3   4    4        NaN  A-4    NaN  40   男性  1/26/2020  1/23/2020    愛知県
# 4   5    5        NaN  A-5    NaN  40   男性  1/28/2020  1/22/2020    愛知県
#
#     ...               更新日時 Field2 Field3 Field4 Field5 Field6 Field7 Field8  \
# 0   ...    3/15/2020 20:13    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1   ...                NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2   ...                NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3   ...                NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4   ...                NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#   Field9 Field10
# 0    NaN     NaN
# 1    NaN     NaN
# 2    NaN     NaN
# 3    NaN     NaN
# 4    NaN     NaN
#
# [5 rows x 50 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 809 entries, 0 to 808
# Data columns (total 50 columns):
# 通し                  809 non-null int64
# 厚労省NO               459 non-null object
# 無症状病原体保有者           75 non-null object
# 国内                  301 non-null object
# チャーター便              12 non-null object
# 年代                  809 non-null object
# 性別                  809 non-null object
# 確定日                 809 non-null object
# 発症日                 640 non-null object
# 受診都道府県              809 non-null object
# 居住都道府県              809 non-null object
# 居住管内                79 non-null object
# 居住市区町村              534 non-null object
# キー                  809 non-null object
# 発表                  809 non-null object
# ステータス               64 non-null object
# 備考                  150 non-null object
# ソース                 648 non-null object
# ソース2                715 non-null object
# ソース3                99 non-null object
# 人数                  804 non-null float64
# 累計                  809 non-null int64
# 前日比                 809 non-null int64
# 死者合計                58 non-null float64
# 退院数累計               33 non-null float64
# 退院数                 33 non-null float64
# 発症数                 809 non-null int64
# PCR検査実施人数           11 non-null float64
# Field1              11 non-null float64
# 職業_正誤確認用            87 non-null object
# 勤務先_正誤確認用           2 non-null object
# Hospital Pref       808 non-null object
# Residential Pref    808 non-null object
# Release             808 non-null object
# Gender              809 non-null object
# X                   809 non-null float64
# Y                   809 non-null float64
# 確定日YYYYMMDD         809 non-null object
# 受診都道府県コード           802 non-null float64
# 居住都道府県コード           782 non-null float64
# 更新日時                1 non-null object
# Field2              167 non-null object
# Field3              0 non-null float64
# Field4              0 non-null float64
# Field5              0 non-null float64
# Field6              0 non-null float64
# Field7              0 non-null float64
# Field8              0 non-null float64
# Field9              0 non-null float64
# Field10             0 non-null float64
# dtypes: float64(18), int64(4), object(28)
# memory usage: 316.1+ KB

# %% [markdown]
# ## 症状別累計人数

# %%
total = data["累計"].iloc[-1]
d = data["死者合計"].dropna().iloc[-1]
di = data["退院数累計"].dropna().iloc[-1]
print(data["確定日"].iloc[-1],"現在データ")
print('全国の新型コロナウイルス感染者はトータル:',total,'死者合計:',d,'累計退院者数:',di)
print('死亡確率：{}%'.format((d/total)*100),'退院率：{}%'.format((di/total)*100))
# Out:
# 3/15/2020 現在データ
# 全国の新型コロナウイルス感染者はトータル: 809 死者合計: 21.0 累計退院者数: 144.0
# 死亡確率：2.595797280593325% 退院率：17.79975278121137%

# %% [markdown]
# ## 日別感染者累計

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.plot(data['確定日'],data['累計'])
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, fontsize=10);

# %% [markdown]
# ## 死亡者推移

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.bar(data['確定日'],data["死者合計"])
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, fontsize=10);

# %% [markdown]
# ## 感染者、死亡推移

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.bar(data['確定日'],data["死者合計"])
ax.plot(data['確定日'],data['累計'])
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, fontsize=10);

# %% [markdown]
# ## 年代別感染者数割合

# %%
x = data['年代'].value_counts(ascending=True)
label_index = data['年代'].value_counts(ascending=True).index
plt.figure(figsize=(10,10))
plt.pie(x, labels= label_index, startangle=90, labeldistance=1,rotatelabels=False,autopct='%.2f%%')
plt.legend()
plt.show()

# %% [markdown]
# ## 性別感染者数割合

# %%
x = data['性別'].value_counts(ascending=True)
label_index = data['性別'].value_counts(ascending=True).index
plt.figure(figsize=(10,10))
plt.pie(x, labels= label_index, startangle=90, labeldistance=1,rotatelabels=False,autopct='%.2f%%')
plt.legend()
plt.show()

# %% [markdown]
# ### 県別累計データ

# %%
grouped = data['人数'].groupby(data['居住都道府県'])
total_pref = grouped.sum()
total_pref = total_pref.sort_values(ascending=False) 
total_pref = pd.DataFrame(total_pref)
total_pref
# Out:
#             人数
# 居住都道府県
# 北海道      146.0
# 愛知県      118.0
# 大阪府      105.0
# 東京都       90.0
# 兵庫県       75.0
# 神奈川県      55.0
# 埼玉県       32.0
# 千葉県       29.0
# 中華人民共和国   18.0
# 京都府       16.0
# 和歌山県      15.0
# 新潟県       15.0
# 高知県       11.0
# 三重県        9.0
# 奈良県        8.0
# 不明         6.0
# 熊本県        6.0
# 石川県        6.0
# 群馬県        5.0
# 長野県        4.0
# 沖縄県        3.0
# 調査中        3.0
# 福岡県        3.0
# 山口県        3.0
# 秋田県        2.0
# 福島県        2.0
# 栃木県        2.0
# 山梨県        2.0
# 静岡県        2.0
# 愛媛県        2.0
# 滋賀県        2.0
# 宮城県        1.0
# 宮崎県        1.0
# 大分県        1.0
# 岐阜県        1.0
# 岡山県        1.0
# 徳島県        1.0
# 佐賀県        1.0
# 長崎県        1.0
# 広島県        1.0

# %%
location_data = pd.read_csv('./location.csv')
location_data.head()
# Out:
#   都道府県名        緯度         経度
# 0   北海道  43.06417  141.34694
# 1   青森県  40.82444  140.74000
# 2   岩手県  39.70361  141.15250
# 3   宮城県  38.26889  140.87194
# 4   秋田県  39.71861  140.10250

# %% [markdown]
# ### locationデータと感染者数をマージ

# %%
pref_data = pd.merge(total_pref, location_data, left_on='居住都道府県', right_on='都道府県名', how='outer')
pref_data['人数'] = pref_data['人数'].fillna(0)
pref_data = pref_data.dropna(subset=['都道府県名'])
pref_data
# Out:
#        人数 都道府県名        緯度         経度
# 0   146.0   北海道  43.06417  141.34694
# 1   118.0   愛知県  35.18028  136.90667
# 2   105.0   大阪府  34.68639  135.52000
# 3    90.0   東京都  35.68944  139.69167
# 4    75.0   兵庫県  34.69139  135.18306
# 5    55.0  神奈川県  35.44778  139.64250
# 6    32.0   埼玉県  35.85694  139.64889
# 7    29.0   千葉県  35.60472  140.12333
# 9    16.0   京都府  35.02139  135.75556
# 10   15.0  和歌山県  34.22611  135.16750
# 11   15.0   新潟県  37.90222  139.02361
# 12   11.0   高知県  33.55972  133.53111
# 13    9.0   三重県  34.73028  136.50861
# 14    8.0   奈良県  34.68528  135.83278
# 16    6.0   熊本県  32.78972  130.74167
# 17    6.0   石川県  36.59444  136.62556
# 18    5.0   群馬県  36.39111  139.06083
# 19    4.0   長野県  36.65139  138.18111
# 20    3.0   沖縄県  26.21250  127.68111
# 22    3.0   福岡県  33.60639  130.41806
# 23    3.0   山口県  34.18583  131.47139
# 24    2.0   秋田県  39.71861  140.10250
# 25    2.0   福島県  37.75000  140.46778
# 26    2.0   栃木県  36.56583  139.88361
# 27    2.0   山梨県  35.66389  138.56833
# 28    2.0   静岡県  34.97694  138.38306
# 29    2.0   愛媛県  33.84167  132.76611
# 30    2.0   滋賀県  35.00444  135.86833
# 31    1.0   宮城県  38.26889  140.87194
# 32    1.0   宮崎県  31.91111  131.42389
# 33    1.0   大分県  33.23806  131.61250
# 34    1.0   岐阜県  35.39111  136.72222
# 35    1.0   岡山県  34.66167  133.93500
# 36    1.0   徳島県  34.06583  134.55944
# 37    1.0   佐賀県  33.24944  130.29889
# 38    1.0   長崎県  32.74472  129.87361
# 39    1.0   広島県  34.39639  132.45944
# 40    0.0   青森県  40.82444  140.74000
# 41    0.0   岩手県  39.70361  141.15250
# 42    0.0   山形県  38.24056  140.36333
# 43    0.0   茨城県  36.34139  140.44667
# 44    0.0   富山県  36.69528  137.21139
# 45    0.0   福井県  36.06528  136.22194
# 46    0.0   鳥取県  35.50361  134.23833
# 47    0.0   島根県  35.47222  133.05056
# 48    0.0   香川県  34.34028  134.04333
# 49    0.0  鹿児島県  31.56028  130.55806

# %%
pref_data_dic = pref_data.to_dict(orient='index')
states = tuple(pref_data_dic.values())

# %%
import folium
from folium.plugins import HeatMap

map_ = folium.Map(location=[35.684479, 139.747977], zoom_start=5)


# 円の大きさをわかりやすくするための重み
WEIGHT = 0.01

for state in states:
    folium.CircleMarker(
            [state['緯度'], state['経度']],
            radius=state['人数'] + WEIGHT,
            popup=state['都道府県名'],
            color='#3186cc',
            fill_color='#3186cc',
    ).add_to(map_)


map_.save('index.html')
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
