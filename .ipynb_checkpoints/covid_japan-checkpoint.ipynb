# %% [markdown]
# # 全国新型コロナウイルスデータ

# %% [markdown]
# ## jsonデータを読み込み

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['font.family'] = 'AppleGothic'


data = pd.read_csv('./COVID-19.csv')
data.head()
# Out:
#    通し 厚労省NO 無症状病原体保有者   国内 チャーター便   年代  性別        確定日        発症日 受診都道府県  \
# 0   1     1       NaN  A-1    NaN  30   男性  1/15/2020   1/3/2020   神奈川県
# 1   2     2       NaN  A-2    NaN  40   男性  1/24/2020  1/14/2020    東京都
# 2   3     3       NaN  A-3    NaN  30   女性  1/25/2020  1/21/2020    東京都
# 3   4     4       NaN  A-4    NaN  40   男性  1/26/2020  1/23/2020    愛知県
# 4   5     5       NaN  A-5    NaN  40   男性  1/28/2020  1/22/2020    愛知県
#
#     居住都道府県 居住管内 居住市区町村       キー    発表 ステータス   備考  \
# 0     神奈川県  NaN    NaN     神奈川県  神奈川県    退院  NaN
# 1  中華人民共和国  NaN    NaN  中華人民共和国   東京都   NaN  NaN
# 2  中華人民共和国  NaN    NaN  中華人民共和国   東京都   NaN  NaN
# 3  中華人民共和国  NaN    NaN  中華人民共和国   愛知県   NaN  NaN
# 4  中華人民共和国  NaN    NaN  中華人民共和国   愛知県   NaN  NaN
#
#                                              ソース  \
# 0  https://www.mhlw.go.jp/stf/newpage_08906.html
# 1  https://www.mhlw.go.jp/stf/newpage_09079.html
# 2  https://www.mhlw.go.jp/stf/newpage_09099.html
# 3  https://www.mhlw.go.jp/stf/newpage_09100.html
# 4  https://www.mhlw.go.jp/stf/newpage_09154.html
#
#                                                 ソース2 ソース3   人数  累計  前日比  死者合計  \
# 0  https://www.pref.kanagawa.jp/docs/ga4/bukanshi...  NaN  1.0   1    1   0.0
# 1  https://www.metro.tokyo.lg.jp/tosei/hodohappyo...  NaN  1.0   2    1   0.0
# 2  https://www.metro.tokyo.lg.jp/tosei/hodohappyo...  NaN  1.0   3    1   0.0
# 3  https://www.pref.aichi.jp/uploaded/attachment/...  NaN  1.0   4    1   0.0
# 4  https://www.pref.aichi.jp/uploaded/attachment/...  NaN  1.0   5    3   0.0
#
#    退院数累計  退院数  発症数  PCR検査実施人数  Field1 職業_正誤確認用 勤務先_正誤確認用 Hospital Pref  \
# 0    1.0  1.0    0        NaN     NaN      NaN       NaN      Kanagawa
# 1    NaN  NaN    2        NaN     NaN      NaN       NaN         Tokyo
# 2    NaN  NaN    1        NaN     NaN      NaN       NaN         Tokyo
# 3    NaN  NaN    3        NaN     NaN      NaN       NaN         Aichi
# 4    NaN  NaN    1        NaN     NaN      NaN       NaN         Aichi
#
#   Residential Pref                        Release  Gender           X  \
# 0         Kanagawa            Kanagawa Prefecture    Male  139.642347
# 1            Tokyo  Tokyo Metropolitan Government    Male  116.409685
# 2            Tokyo  Tokyo Metropolitan Government  Female  116.409685
# 3            Aichi               Aichi Prefecture    Male  116.409685
# 4            Aichi               Aichi Prefecture    Male  116.409685
#
#            Y 確定日YYYYMMDD  受診都道府県コード  居住都道府県コード            更新日時  Field2  \
# 0  35.447504   2020/1/15       14.0       14.0  3/7/2020 20:01     NaN
# 1  39.903832   2020/1/24       13.0        NaN             NaN     NaN
# 2  39.903832   2020/1/25       13.0        NaN             NaN     NaN
# 3  39.903832   2020/1/26       23.0        NaN             NaN     NaN
# 4  39.903832   2020/1/28       23.0        NaN             NaN     NaN
#
#    Field3  Field4  Field5  Field6  Field7  Field8  Field9  Field10
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN      NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN      NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN      NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN      NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN      NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 50 columns):
# 通し                  441 non-null int64
# 厚労省NO               387 non-null object
# 無症状病原体保有者           39 non-null object
# 国内                  301 non-null object
# チャーター便              12 non-null object
# 年代                  441 non-null object
# 性別                  441 non-null object
# 確定日                 441 non-null object
# 発症日                 337 non-null object
# 受診都道府県              441 non-null object
# 居住都道府県              441 non-null object
# 居住管内                65 non-null object
# 居住市区町村              223 non-null object
# キー                  441 non-null object
# 発表                  441 non-null object
# ステータス               22 non-null object
# 備考                  105 non-null object
# ソース                 361 non-null object
# ソース2                387 non-null object
# ソース3                40 non-null object
# 人数                  439 non-null float64
# 累計                  441 non-null int64
# 前日比                 441 non-null int64
# 死者合計                440 non-null float64
# 退院数累計               25 non-null float64
# 退院数                 25 non-null float64
# 発症数                 441 non-null int64
# PCR検査実施人数           3 non-null float64
# Field1              3 non-null float64
# 職業_正誤確認用            73 non-null object
# 勤務先_正誤確認用           1 non-null object
# Hospital Pref       440 non-null object
# Residential Pref    440 non-null object
# Release             440 non-null object
# Gender              441 non-null object
# X                   441 non-null float64
# Y                   441 non-null float64
# 確定日YYYYMMDD         441 non-null object
# 受診都道府県コード           434 non-null float64
# 居住都道府県コード           416 non-null float64
# 更新日時                1 non-null object
# Field2              0 non-null float64
# Field3              0 non-null float64
# Field4              0 non-null float64
# Field5              0 non-null float64
# Field6              0 non-null float64
# Field7              0 non-null float64
# Field8              0 non-null float64
# Field9              0 non-null float64
# Field10             0 non-null float64
# dtypes: float64(19), int64(4), object(27)
# memory usage: 172.3+ KB

# %% [markdown]
# ## 症状別累計人数

# %%
total = len(data)
d = (data["ステータス"].str.contains('死亡')).sum()
di = (data["ステータス"].str.contains('退院')).sum()
print(data["確定日"].iloc[-1],"現在データ")
print('全国の新型コロナウイルス感染者はトータル:',total,'死亡:',d,'退院:',di)
print('死亡確率：{}%'.format((d/total)*100),'退院率：{}%'.format((di/total)*100))
# Out:
# 3/7/2020 現在データ
# 全国の新型コロナウイルス感染者はトータル: 441 死亡: 6 退院: 15
# 死亡確率：1.3605442176870748% 退院率：3.4013605442176873%

# %% [markdown]
# ## 年代別感染者数割合

# %%
x = data['年代'].value_counts(ascending=True)
label_index = data['年代'].value_counts(ascending=True).index
plt.figure(figsize=(10,10))
plt.pie(x, labels= label_index, startangle=90, labeldistance=1,rotatelabels=False,autopct='%.2f%%')
plt.legend()
plt.show()

# %% [markdown]
# ## 性別感染者数割合

# %%
x = data['性別'].value_counts(ascending=True)
label_index = data['性別'].value_counts(ascending=True).index
plt.figure(figsize=(10,10))
plt.pie(x, labels= label_index, startangle=90, labeldistance=1,rotatelabels=False,autopct='%.2f%%')
plt.legend()
plt.show()

# %% [markdown]
# ### 県別累計データ

# %%
grouped = data['人数'].groupby(data['居住都道府県'])
total_pref = grouped.sum()
total_pref = total_pref.sort_values(ascending=False) 
total_pref = pd.DataFrame(total_pref)
total_pref
# Out:
#            人数
# 居住都道府県
# 北海道      96.0
# 東京都      64.0
# 愛知県      60.0
# 神奈川県     40.0
# 大阪府      34.0
# 千葉県      19.0
# 中華人民共和国  18.0
# 和歌山県     14.0
# 高知県      10.0
# 埼玉県       9.0
# 兵庫県       8.0
# 京都府       7.0
# 熊本県       6.0
# 石川県       5.0
# 新潟県       5.0
# 不明        4.0
# 奈良県       4.0
# 山口県       3.0
# 沖縄県       3.0
# 福岡県       3.0
# 調査中       3.0
# 長野県       3.0
# 三重県       2.0
# 愛媛県       2.0
# 栃木県       2.0
# 滋賀県       2.0
# 秋田県       2.0
# 山梨県       1.0
# 宮崎県       1.0
# 宮城県       1.0
# 岐阜県       1.0
# 岡山県       1.0
# 大分県       1.0
# 静岡県       1.0
# 徳島県       1.0
# 福島県       1.0
# 群馬県       1.0
# 広島県       1.0

# %%
location_data = pd.read_csv('./location.csv')
location_data.head()
# Out:
#   都道府県名        緯度         経度
# 0   北海道  43.06417  141.34694
# 1   青森県  40.82444  140.74000
# 2   岩手県  39.70361  141.15250
# 3   宮城県  38.26889  140.87194
# 4   秋田県  39.71861  140.10250

# %% [markdown]
# ### locationデータと感染者数をマージ

# %%
pref_data = pd.merge(total_pref, location_data, left_on='居住都道府県', right_on='都道府県名', how='outer')
pref_data['人数'] = pref_data['人数'].fillna(0)
pref_data = pref_data.dropna(subset=['都道府県名'])
pref_data
# Out:
#       人数 都道府県名        緯度         経度
# 0   96.0   北海道  43.06417  141.34694
# 1   64.0   東京都  35.68944  139.69167
# 2   60.0   愛知県  35.18028  136.90667
# 3   40.0  神奈川県  35.44778  139.64250
# 4   34.0   大阪府  34.68639  135.52000
# 5   19.0   千葉県  35.60472  140.12333
# 7   14.0  和歌山県  34.22611  135.16750
# 8   10.0   高知県  33.55972  133.53111
# 9    9.0   埼玉県  35.85694  139.64889
# 10   8.0   兵庫県  34.69139  135.18306
# 11   7.0   京都府  35.02139  135.75556
# 12   6.0   熊本県  32.78972  130.74167
# 13   5.0   石川県  36.59444  136.62556
# 14   5.0   新潟県  37.90222  139.02361
# 16   4.0   奈良県  34.68528  135.83278
# 17   3.0   山口県  34.18583  131.47139
# 18   3.0   沖縄県  26.21250  127.68111
# 19   3.0   福岡県  33.60639  130.41806
# 21   3.0   長野県  36.65139  138.18111
# 22   2.0   三重県  34.73028  136.50861
# 23   2.0   愛媛県  33.84167  132.76611
# 24   2.0   栃木県  36.56583  139.88361
# 25   2.0   滋賀県  35.00444  135.86833
# 26   2.0   秋田県  39.71861  140.10250
# 27   1.0   山梨県  35.66389  138.56833
# 28   1.0   宮崎県  31.91111  131.42389
# 29   1.0   宮城県  38.26889  140.87194
# 30   1.0   岐阜県  35.39111  136.72222
# 31   1.0   岡山県  34.66167  133.93500
# 32   1.0   大分県  33.23806  131.61250
# 33   1.0   静岡県  34.97694  138.38306
# 34   1.0   徳島県  34.06583  134.55944
# 35   1.0   福島県  37.75000  140.46778
# 36   1.0   群馬県  36.39111  139.06083
# 37   1.0   広島県  34.39639  132.45944
# 38   0.0   青森県  40.82444  140.74000
# 39   0.0   岩手県  39.70361  141.15250
# 40   0.0   山形県  38.24056  140.36333
# 41   0.0   茨城県  36.34139  140.44667
# 42   0.0   富山県  36.69528  137.21139
# 43   0.0   福井県  36.06528  136.22194
# 44   0.0   鳥取県  35.50361  134.23833
# 45   0.0   島根県  35.47222  133.05056
# 46   0.0   香川県  34.34028  134.04333
# 47   0.0   佐賀県  33.24944  130.29889
# 48   0.0   長崎県  32.74472  129.87361
# 49   0.0  鹿児島県  31.56028  130.55806

# %%
pref_data_dic = pref_data.to_dict(orient='index')
states = tuple(pref_data_dic.values())

# %%
import folium
from folium.plugins import HeatMap

map_ = folium.Map(location=[35.684479, 139.747977], zoom_start=5, tiles='Stamen Toner')


# 円の大きさをわかりやすくするための重み
WEIGHT = 1

for state in states:
    folium.CircleMarker(
            [state['緯度'], state['経度']],
            radius=state['人数'] * WEIGHT,
            popup=state['都道府県名'],
            color='#3186cc',
            fill_color='#3186cc',
    ).add_to(map_)


map_.save('index.html')
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
