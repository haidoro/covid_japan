# %% [markdown]
# # 全国新型コロナウイルスデータ

# %% [markdown]
# ## jsonデータを読み込み

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['font.family'] = 'AppleGothic'

pcr = pd.read_csv('./PCR.csv')
data = pd.read_csv('./COVID-19.csv')
data_pcr = pd.merge(pcr, data, right_on='確定日',left_on='年月日')
data.head()
# Out:
#    通し 厚労省NO 無症状病原体保有者   国内 チャーター便   年代  性別        確定日        発症日 受診都道府県  \
# 0   1    1        NaN  A-1    NaN  30   男性  1/15/2020   1/3/2020   神奈川県
# 1   2    2        NaN  A-2    NaN  40   男性  1/24/2020  1/14/2020    東京都
# 2   3    3        NaN  A-3    NaN  30   女性  1/25/2020  1/21/2020    東京都
# 3   4    4        NaN  A-4    NaN  40   男性  1/26/2020  1/23/2020    愛知県
# 4   5    5        NaN  A-5    NaN  40   男性  1/28/2020  1/22/2020    愛知県
#
#     ...               更新日時 Field2 Field3 Field4 Field5 Field6 Field7 Field8  \
# 0   ...    3/20/2020 21:46    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1   ...                NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2   ...                NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3   ...                NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4   ...                NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#   Field9 Field10
# 0    NaN     NaN
# 1    NaN     NaN
# 2    NaN     NaN
# 3    NaN     NaN
# 4    NaN     NaN
#
# [5 rows x 50 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1012 entries, 0 to 1011
# Data columns (total 50 columns):
# 通し                  1012 non-null int64
# 厚労省NO               900 non-null object
# 無症状病原体保有者           91 non-null object
# 国内                  302 non-null object
# チャーター便              11 non-null object
# 年代                  1012 non-null object
# 性別                  1012 non-null object
# 確定日                 1012 non-null object
# 発症日                 763 non-null object
# 受診都道府県              1012 non-null object
# 居住都道府県              1012 non-null object
# 居住管内                81 non-null object
# 居住市区町村              651 non-null object
# キー                  1012 non-null object
# 発表                  1012 non-null object
# ステータス               70 non-null object
# 備考                  190 non-null object
# ソース                 927 non-null object
# ソース2                803 non-null object
# ソース3                154 non-null object
# 人数                  1012 non-null int64
# 累計                  51 non-null float64
# 前日比                 51 non-null float64
# 死者合計                49 non-null float64
# 退院数累計               39 non-null float64
# 退院数                 39 non-null float64
# 発症数                 51 non-null float64
# PCR検査実施人数           17 non-null float64
# Field1              17 non-null object
# 職業_正誤確認用            92 non-null object
# 勤務先_正誤確認用           2 non-null object
# Hospital Pref       1012 non-null object
# Residential Pref    1012 non-null object
# Release             1012 non-null object
# Gender              1012 non-null object
# X                   1012 non-null float64
# Y                   1012 non-null float64
# 確定日YYYYMMDD         1012 non-null object
# 受診都道府県コード           1005 non-null float64
# 居住都道府県コード           976 non-null float64
# 更新日時                1 non-null object
# Field2              393 non-null object
# Field3              0 non-null float64
# Field4              0 non-null float64
# Field5              0 non-null float64
# Field6              0 non-null float64
# Field7              0 non-null float64
# Field8              0 non-null float64
# Field9              0 non-null float64
# Field10             0 non-null float64
# dtypes: float64(19), int64(2), object(29)
# memory usage: 395.4+ KB

# %% [markdown]
# ## 症状別累計人数

# %%
total = data["累計"].iloc[-1]
d = data["死者合計"].dropna().iloc[-1]
di = data["退院数累計"].dropna().iloc[-1]
print(data["確定日"].iloc[-1],"現在データ")
print('全国の新型コロナウイルス感染者はトータル:',total,'死者合計:',d,'累計退院者数:',di)
print('死亡確率：{}%'.format((d/total)*100),'退院率：{}%'.format((di/total)*100))
# Out:
# 3/20/2020 現在データ
# 全国の新型コロナウイルス感染者はトータル: 1012.0 死者合計: 33.0 累計退院者数: 227.0
# 死亡確率：3.260869565217391% 退院率：22.43083003952569%

# %% [markdown]
# ## 日別PCR検査数
# 厚生労働省の発表資料より

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.plot(pcr['年月日'],pcr['数'])
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, fontsize=10);

# %% [markdown]
# ## 累計PCR検査数

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.plot(pcr['年月日'],pcr['PCR累計'])
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, fontsize=10);

# %% [markdown]
# ## 日別感染者累計

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.bar(data['確定日'],data['累計'])
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, fontsize=10);

# %% [markdown]
# ## 死亡者推移

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.bar(data['確定日'],data["死者合計"])
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, fontsize=10);

# %% [markdown]
# ## 年代別感染者数割合

# %%
x = data['年代'].value_counts(ascending=True)
label_index = data['年代'].value_counts(ascending=True).index
plt.figure(figsize=(10,10))
plt.pie(x, labels= label_index, startangle=90, labeldistance=1,rotatelabels=False,autopct='%.2f%%')
plt.legend()
plt.show()

# %% [markdown]
# ## 性別感染者数割合

# %%
x = data['性別'].value_counts(ascending=True)
label_index = data['性別'].value_counts(ascending=True).index
plt.figure(figsize=(10,10))
plt.pie(x, labels= label_index, startangle=90, labeldistance=1,rotatelabels=False,autopct='%.2f%%')
plt.legend()
plt.show()

# %% [markdown]
# ### 県別累計データ

# %%
grouped = data['人数'].groupby(data['居住都道府県'])
total_pref = grouped.sum()
total_pref = total_pref.sort_values(ascending=False) 
total_pref = pd.DataFrame(total_pref)
total_pref
# Out:
#           人数
# 居住都道府県
# 北海道      156
# 愛知県      138
# 東京都      129
# 大阪府      127
# 兵庫県      100
# 神奈川県      71
# 埼玉県       45
# 千葉県       36
# 新潟県       24
# 京都府       19
# 中華人民共和国   18
# 和歌山県      17
# 不明        13
# 高知県       11
# 群馬県       11
# 三重県       10
# 大分県        8
# 奈良県        8
# 熊本県        7
# 石川県        7
# 福岡県        5
# 滋賀県        5
# 栃木県        4
# 長野県        4
# 調査中        3
# 愛媛県        3
# 沖縄県        3
# 山口県        3
# 宮崎県        3
# 茨城県        3
# 静岡県        2
# 福島県        2
# 山梨県        2
# 岐阜県        2
# 秋田県        2
# 広島県        2
# スペイン       1
# 佐賀県        1
# 徳島県        1
# 宮城県        1
# 岡山県        1
# 香川県        1
# 福井県        1
# 長崎県        1
# アイルランド     1

# %%
location_data = pd.read_csv('./location.csv')
location_data.head()
# Out:
#   都道府県名        緯度         経度
# 0   北海道  43.06417  141.34694
# 1   青森県  40.82444  140.74000
# 2   岩手県  39.70361  141.15250
# 3   宮城県  38.26889  140.87194
# 4   秋田県  39.71861  140.10250

# %% [markdown]
# ### locationデータと感染者数をマージ

# %%
pref_data = pd.merge(total_pref, location_data, left_on='居住都道府県', right_on='都道府県名', how='outer')
pref_data['人数'] = pref_data['人数'].fillna(0)
pref_data = pref_data.dropna(subset=['都道府県名'])
pref_data
# Out:
#        人数 都道府県名        緯度         経度
# 0   156.0   北海道  43.06417  141.34694
# 1   138.0   愛知県  35.18028  136.90667
# 2   129.0   東京都  35.68944  139.69167
# 3   127.0   大阪府  34.68639  135.52000
# 4   100.0   兵庫県  34.69139  135.18306
# 5    71.0  神奈川県  35.44778  139.64250
# 6    45.0   埼玉県  35.85694  139.64889
# 7    36.0   千葉県  35.60472  140.12333
# 8    24.0   新潟県  37.90222  139.02361
# 9    19.0   京都府  35.02139  135.75556
# 11   17.0  和歌山県  34.22611  135.16750
# 13   11.0   高知県  33.55972  133.53111
# 14   11.0   群馬県  36.39111  139.06083
# 15   10.0   三重県  34.73028  136.50861
# 16    8.0   大分県  33.23806  131.61250
# 17    8.0   奈良県  34.68528  135.83278
# 18    7.0   熊本県  32.78972  130.74167
# 19    7.0   石川県  36.59444  136.62556
# 20    5.0   福岡県  33.60639  130.41806
# 21    5.0   滋賀県  35.00444  135.86833
# 22    4.0   栃木県  36.56583  139.88361
# 23    4.0   長野県  36.65139  138.18111
# 25    3.0   愛媛県  33.84167  132.76611
# 26    3.0   沖縄県  26.21250  127.68111
# 27    3.0   山口県  34.18583  131.47139
# 28    3.0   宮崎県  31.91111  131.42389
# 29    3.0   茨城県  36.34139  140.44667
# 30    2.0   静岡県  34.97694  138.38306
# 31    2.0   福島県  37.75000  140.46778
# 32    2.0   山梨県  35.66389  138.56833
# 33    2.0   岐阜県  35.39111  136.72222
# 34    2.0   秋田県  39.71861  140.10250
# 35    2.0   広島県  34.39639  132.45944
# 37    1.0   佐賀県  33.24944  130.29889
# 38    1.0   徳島県  34.06583  134.55944
# 39    1.0   宮城県  38.26889  140.87194
# 40    1.0   岡山県  34.66167  133.93500
# 41    1.0   香川県  34.34028  134.04333
# 42    1.0   福井県  36.06528  136.22194
# 43    1.0   長崎県  32.74472  129.87361
# 45    0.0   青森県  40.82444  140.74000
# 46    0.0   岩手県  39.70361  141.15250
# 47    0.0   山形県  38.24056  140.36333
# 48    0.0   富山県  36.69528  137.21139
# 49    0.0   鳥取県  35.50361  134.23833
# 50    0.0   島根県  35.47222  133.05056
# 51    0.0  鹿児島県  31.56028  130.55806

# %%
pref_data_dic = pref_data.to_dict(orient='index')
states = tuple(pref_data_dic.values())

# %% [markdown]
# ## 県別感染者数Map表示
# Map表示はGitHubではできませんので、次のリンクから確認ください。
#
# [県別感染者数Map](https://haidoro.github.io/covid_japan/)

# %%
import folium
from folium.plugins import HeatMap

map_ = folium.Map(location=[35.684479, 139.747977], zoom_start=5)


# 円の大きさをわかりやすくするための重み
WEIGHT = 0.01

for state in states:
    folium.CircleMarker(
            [state['緯度'], state['経度']],
            radius=state['人数'] + WEIGHT,
            popup=state['都道府県名'],
            color='#3186cc',
            fill_color='#3186cc',
    ).add_to(map_)


map_.save('index.html')
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
